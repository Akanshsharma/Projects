# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanshsharma/Projects/blob/main/python_for_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-46fec2e1-7dbe-446d-858c-719a12d29b8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46fec2e1-7dbe-446d-858c-719a12d29b8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HistoricalData_1647065041117.csv to HistoricalData_1647065041117.csv

# %%
import pandas as pd
import re 
amzn = pd.read_csv ('HistoricalData_1647003243498.csv')

# %%
amzn.head()
# Out:
#          Date Close/Last   Volume      Open       High       Low
# 0  03/10/2022   $2936.35  6753145   $2913.7  $2973.485  $2879.56
# 1  03/09/2022   $2785.58  4132833     $2790      $2805  $2736.56
# 2  03/08/2022   $2720.29  4583129  $2733.67   $2813.99  $2671.45
# 3  03/07/2022   $2749.06  4346693  $2908.87   $2921.89  $2748.33
# 4  03/04/2022   $2912.82  3049156  $2943.18      $2957  $2876.14

# %%
amzn.tail()
# Out:
#           Date Close/Last   Volume      Open        High        Low
# 14  02/17/2022   $3093.05  3201625  $3162.92   $3206.975      $3090
# 15  02/16/2022   $3162.01  2635214  $3115.81    $3176.68   $3094.69
# 16  02/15/2022   $3130.21  2848533  $3152.11    $3160.14   $3092.75
# 17  02/14/2022   $3103.34  4161535  $3035.02  $3168.9663      $3033
# 18  02/11/2022   $3065.87  3855022  $3162.69       $3180  $3054.675

# %%
amzn.describe()
# Out:
#              Volume
# count  1.900000e+01
# mean   3.588378e+06
# std    1.074694e+06
# min    2.243679e+06
# 25%    2.966664e+06
# 50%    3.212178e+06
# 75%    4.147184e+06
# max    6.753145e+06

# %%
amzn.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
amzn = amzn.replace({'\$':''}, regex = True)

# %%
amzn.head()
# Out:
#          Date Close/Last   Volume     Open      High      Low
# 0  03/10/2022    2936.35  6753145   2913.7  2973.485  2879.56
# 1  03/09/2022    2785.58  4132833     2790      2805  2736.56
# 2  03/08/2022    2720.29  4583129  2733.67   2813.99  2671.45
# 3  03/07/2022    2749.06  4346693  2908.87   2921.89  2748.33
# 4  03/04/2022    2912.82  3049156  2943.18      2957  2876.14

# %%
df = amzn

df.columns = ['Date', 'Close', 'Volume', 'Open', 'High', 'Low']

df = df.astype({"Close": float, "Volume": int, "Open": float, "High": float, "Low": float})

# %%
df.dtypes
# Out:
# Date       object
# Close     float64
# Volume      int64
# Open      float64
# High      float64
# Low       float64
# dtype: object

# %%
df.describe()
# Out:
#              Close        Volume         Open         High          Low
# count    19.000000  1.900000e+01    19.000000    19.000000    19.000000
# mean   2989.850000  3.588378e+06  3003.634211  3052.281911  2940.035526
# std     127.522042  1.074694e+06   126.902144   115.204756   127.770504
# min    2720.290000  2.243679e+06  2733.670000  2805.000000  2671.450000
# 25%    2924.585000  2.966664e+06  2928.440000  3004.232500  2877.850000
# 50%    3027.160000  3.212178e+06  3033.010000  3078.580000  2975.000000
# 75%    3073.515000  4.147184e+06  3090.310000  3135.065000  3025.430000
# max    3162.010000  6.753145e+06  3162.920000  3206.975000  3094.690000

# %%
df.describe(include = "float")
# Out:
#              Close         Open         High          Low
# count    19.000000    19.000000    19.000000    19.000000
# mean   2989.850000  3003.634211  3052.281911  2940.035526
# std     127.522042   126.902144   115.204756   127.770504
# min    2720.290000  2733.670000  2805.000000  2671.450000
# 25%    2924.585000  2928.440000  3004.232500  2877.850000
# 50%    3027.160000  3033.010000  3078.580000  2975.000000
# 75%    3073.515000  3090.310000  3135.065000  3025.430000
# max    3162.010000  3162.920000  3206.975000  3094.690000

# %%
df.describe(include = "object")
# Out:
#               Date
# count           19
# unique          19
# top     03/10/2022
# freq             1

# %%
df.describe(exclude = "int")
# Out:
#               Date        Close         Open         High          Low
# count           19    19.000000    19.000000    19.000000    19.000000
# unique          19          NaN          NaN          NaN          NaN
# top     03/10/2022          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN  2989.850000  3003.634211  3052.281911  2940.035526
# std            NaN   127.522042   126.902144   115.204756   127.770504
# min            NaN  2720.290000  2733.670000  2805.000000  2671.450000
# 25%            NaN  2924.585000  2928.440000  3004.232500  2877.850000
# 50%            NaN  3027.160000  3033.010000  3078.580000  2975.000000
# 75%            NaN  3073.515000  3090.310000  3135.065000  3025.430000
# max            NaN  3162.010000  3162.920000  3206.975000  3094.690000

# %%
df.describe(percentiles = [0.1, 0.5, 0.9])
# Out:
#              Close        Volume         Open         High          Low
# count    19.000000  1.900000e+01    19.000000    19.000000    19.000000
# mean   2989.850000  3.588378e+06  3003.634211  3052.281911  2940.035526
# std     127.522042  1.074694e+06   126.902144   115.204756   127.770504
# min    2720.290000  2.243679e+06  2733.670000  2805.000000  2671.450000
# 10%    2778.276000  2.581518e+06  2795.400000  2900.310000  2745.976000
# 50%    3027.160000  3.212178e+06  3033.010000  3078.580000  2975.000000
# 90%    3108.714000  4.674361e+06  3154.226000  3177.344000  3090.550000
# max    3162.010000  6.753145e+06  3162.920000  3206.975000  3094.690000

# %%
mask_closeprice = df.Close > 3000 
high_price = df.loc[mask_closeprice] 
high_price.head()
# Out:
#           Date    Close   Volume     Open     High      Low
# 6   03/02/2022  3041.05  2366736  3016.98  3059.99  2975.00
# 7   03/01/2022  3022.84  2243679  3054.65  3081.98  2999.54
# 8   02/28/2022  3071.26  2884171  3048.50  3089.00  3017.00
# 9   02/25/2022  3075.77  3119768  3011.00  3079.80  2984.27
# 10  02/24/2022  3027.16  5039288  2796.75  3034.98  2790.00

# %%
mask_closeprice = df.Close > 3000 
mask_volume = df.Volume > 5000000
millionhigh_price_volume = df.loc[mask_closeprice & mask_volume]
high_price_volume.head()
# Out:
#           Date    Close   Volume     Open     High     Low
# 10  02/24/2022  3027.16  5039288  2796.75  3034.98  2790.0

# %%
df.plot(x='Date', y='Close')

# %%
df.plot(x='Date', y='Close', rot=90)

# %%
df.plot(x='Date', y='Close', rot=90, title="AMZN Stock Price")

# %%
df.plot(x='Date', y='Close', kind='scatter', rot=90, title="AMZN Stock Price")

# %%
df.plot(x='Date', y='Volume', kind='hist', rot=90, title="AMZN Stock Price")
